# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 33518, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 33518 (delta 19), reused 49 (delta 9), pack-reused 33387 (from 1)
# Receiving objects: 100% (33518/33518), 58.92 MiB | 19.45 MiB/s, done.
# Resolving deltas: 100% (24054/24054), done.

# %%
# %cd llama.cpp
# Out:
# /content/llama.cpp

# %%
#!make LLAMA_CUBLAS=1
# !make GGML_CUDA=1
# Out:
# I ccache not found. Consider installing it for faster compilation.
# I llama.cpp build info:
# I UNAME_S:   Linux
# I UNAME_P:   x86_64
# I UNAME_M:   x86_64
# I CFLAGS:    -Iggml/include -Iggml/src -Iinclude -Isrc -Icommon -D_XOPEN_SOURCE=600 -D_GNU_SOURCE -DNDEBUG -DGGML_USE_OPENMP -DGGML_USE_LLAMAFILE -DGGML_USE_CUDA -I/usr/local/cuda/include -I/usr/local/cuda/targets/x86_64-linux/include -DGGML_CUDA_USE_GRAPHS  -std=c11   -fPIC -O3 -g -Wall -Wextra -Wpedantic -Wcast-qual -Wno-unused-function -Wshadow -Wstrict-prototypes -Wpointer-arith -Wmissing-prototypes -Werror=implicit-int -Werror=implicit-function-declaration -pthread -march=native -mtune=native -fopenmp -Wdouble-promotion
# ...

# %%
#!wget https://huggingface.co/TheBloke/Wizard-Vicuna-7B-Uncensored-GGML/resolve/main/Wizard-Vicuna-7B-Uncensored.ggmlv3.q4_0.bin
# !wget https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF
# Out:
# --2024-09-09 23:20:38--  https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.23, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 200138 (195K) [text/html]
# Saving to: ‘Llama-2-7B-Chat-GGUF’
#
# Llama-2-7B-Chat-GGU 100%[===================>] 195.45K  --.-KB/s    in 0.07s
#
# 2024-09-09 23:20:38 (2.73 MB/s) - ‘Llama-2-7B-Chat-GGUF’ saved [200138/200138]

# %%
# !ls -la
# Out:
# total 8815780
# drwxr-xr-x 23 root root       4096 Sep  9 23:07 .
# drwxr-xr-x  1 root root       4096 Sep  9 22:27 ..
# -rw-r--r--  1 root root      33717 Sep  9 22:27 AUTHORS
# -rw-r--r--  1 root root      11448 Sep  9 23:04 autogen-main.md
# -rw-r--r--  1 root root      11972 Sep  9 23:04 autogen-server.md
# drwxr-xr-x  2 root root       4096 Sep  9 22:27 ci
# -rw-r--r--  1 root root        791 Sep  9 22:27 .clang-tidy
# drwxr-xr-x  2 root root       4096 Sep  9 22:27 cmake
# -rw-r--r--  1 root root       6440 Sep  9 22:27 CMakeLists.txt
# -rw-r--r--  1 root root       3164 Sep  9 22:27 CMakePresets.json
# drwxr-xr-x  3 root root       4096 Sep  9 23:00 common
# -rw-r--r--  1 root root       2256 Sep  9 22:27 CONTRIBUTING.md
# -rwxr-xr-x  1 root root     190894 Sep  9 22:27 convert_hf_to_gguf.py
# -rwxr-xr-x  1 root root      15149 Sep  9 22:27 convert_hf_to_gguf_update.py
# -rwxr-xr-x  1 root root      19106 Sep  9 22:27 convert_llama_ggml_to_gguf.py
# ...

# %%
#!./main -m Wizard-Vicuna-7B-Uncensored.ggmlv3.q4_0.bin -n 300 -p 'what is life?' -ngl 32
# !./llama-cli -m Wizard-Vicuna-7B-Uncensored.ggmlv3.q4_0.bin -n 300 -p 'what is life?' -ngl 32
# Out:
# Log start
# main: build = 3716 (bfe76d4a)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: seed = 1725923241
# gguf_init_from_file: invalid magic characters 'tjgg'
# llama_model_load: error loading model: llama_model_loader: failed to load model from Wizard-Vicuna-7B-Uncensored.ggmlv3.q4_0.bin
#
# llama_load_model_from_file: failed to load model
# llama_init_from_gpt_params: error: failed to load model 'Wizard-Vicuna-7B-Uncensored.ggmlv3.q4_0.bin'
# main: error: unable to load model
