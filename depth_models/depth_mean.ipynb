# %%
import depth_mean as dp
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# Can call dp.depth_process("model_name", "object_movement", graph=True)

# %%
sword_panover = dp.depth_process("depth_anywhere", "sword_panover")
sword_panover_midas = dp.depth_process("midas", "sword_panover")

# %%
sword_panup = dp.depth_process("depth_anywhere", "sword_panup")
sword_panup_midas = dp.depth_process("midas", "sword_panup")

# %%
garfield = dp.depth_process("depth_anywhere", "garfield_panover")
garfield_midas = dp.depth_process("midas", "garfield_panover")

# %%
garfield_panup = dp.depth_process("depth_anywhere", "garfield_panup")
garfield_panup_midas = dp.depth_process("midas", "garfield_panup")

# %%
sword_rotate = dp.depth_process("depth_anywhere", "sword_rotate")
sword_rotate_midas = dp.depth_process("midas", "sword_rotate")
# Out:
# Setting frame ref mean to 1 since mean + median are both 0
# Setting frame ref mean to 1 since mean + median are both 0
# Setting frame ref mean to 1 since mean + median are both 0
# Setting frame ref mean to 1 since mean + median are both 0

# %%
car_panover = dp.depth_process("depth_anywhere", "car_panover")
car_panover_midas = dp.depth_process("midas", "car_panover")

# %%
# car_cone_panover = dp.depth_process("depth_anywhere", "car_cone_panover")
# car_cone_panover_midas = dp.depth_process("midas", "car_cone_panover")

# compare = [["dashboard", "conetip"], ["leftmirror", "firstorange"], ["logo", "firstwhite"], ["top", "secondwhite"]]
car_cone_panover = dp.depth_process("depth_anywhere", "car_cone_panover", compare = [["dashboard", "firstwhite"]])

# %%
both_panover = dp.depth_process("depth_anywhere", "garfield_sword_panover", compare = [["foot", "rock"], ["head", "pommel"], ["nose", "handle"], ["stomach", "blade"]])
# both_panover_midas = dp.depth_process("midas", "garfield_sword_panover")
